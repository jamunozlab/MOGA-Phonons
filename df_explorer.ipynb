# %%
from pathlib import Path
import yaml
import pandas as pd
import numpy as np

# %%
repo_root = Path.cwd()
df_path = repo_root / "dataframes" / "dataframe000007.pkl"
df = pd.read_pickle(df_path)

# %%
df
# Out:
#            simulation  generation   mass  a_val    alpha0    alpha1     beta1  \
# 0    simulation000294           1   50.0    2.0  1.024208 -0.262959  0.033770
# 1    simulation000294           2   50.0    2.0  7.796451 -0.446250 -0.409717
# 2    simulation000294           3   50.0    2.0  1.024208  0.770048 -0.198211
# 3    simulation000294           4   50.0    2.0  1.024208  0.770048 -0.198211
# 4    simulation000294           5   50.0    2.0  8.237321 -0.446250 -0.409717
# ..                ...         ...    ...    ...       ...       ...       ...
# 820  simulation000335          16  100.0    3.2  5.370975 -0.309839  0.421914
# 821  simulation000335          17  100.0    3.2  5.370975 -0.309839  0.421914
# 822  simulation000335          18  100.0    3.2  5.370975 -0.309839  0.421914
# 823  simulation000335          19  100.0    3.2  5.370975 -0.309839  0.421914
# 824  simulation000335          20  100.0    3.2  5.370975 -0.309839  0.421914
#
# ...

# %%
df.groupby("generation")["num_imaginary"].mean()
# Out:
# generation
# 1     387.238095
# 2     402.238095
# 3     439.333333
# 4     426.902439
# 5     375.880952
# 6     356.976190
# 7     332.609756
# 8     236.238095
# 9     201.595238
# 10    201.317073
# 11    185.682927
# 12    187.560976
# 13    194.523810
# 14    176.595238
# 15    237.902439
# 16    217.425000
# 17    190.658537
# 18    195.325000
# 19    165.975000
# 20    182.175000
# Name: num_imaginary, dtype: float64
